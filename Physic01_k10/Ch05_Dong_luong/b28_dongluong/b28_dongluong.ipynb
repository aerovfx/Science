# %% [markdown]
# # Bài 28: Động Lượng
#
# ## 1. Động Lượng
#
# :::{note}
# **Động lượng** là đại lượng đặc trưng cho trạng thái chuyển động của một vật, được xác định bởi tích của khối lượng và vận tốc của vật.
# :::
#
# **Công thức tính động lượng**:
#
# $$
# \mathbf{p} = m \mathbf{v}
# $$
#
# Trong đó:
# - $\mathbf{p}$ là **động lượng** (kg·m/s).
# - $m$ là **khối lượng** của vật (kg).
# - $\mathbf{v}$ là **vận tốc** của vật (m/s).
#
# ### **Tính chất của động lượng:**
# - Động lượng là đại lượng **vector**, có **hướng trùng với vận tốc** của vật.
# - Nếu một vật có khối lượng lớn hoặc có tốc độ cao thì động lượng của nó cũng **lớn**.
# - Khi không có ngoại lực tác dụng, **động lượng của hệ cô lập được bảo toàn**.
#
# ---
#
# ## 2. Xung Lượng Của Lực
#
# :::{admonition} Định nghĩa 📌
# **Xung lượng của lực** tác dụng lên một vật trong một khoảng thời gian là tích của lực và thời gian tác dụng của lực.
# :::
#
# **Công thức tính xung lượng của lực**:
#
# $$
# \mathbf{I} = \mathbf{F} \Delta t
# $$
#
# Trong đó:
# - $\mathbf{I}$ là **xung lượng của lực** (N·s).
# - $\mathbf{F}$ là **lực tác dụng** (N).
# - $\Delta t$ là **thời gian lực tác dụng** (s).
#
# :::{tip}
# **Mối liên hệ giữa xung lượng và động lượng**:
# Xung lượng của lực bằng **độ biến thiên động lượng** của vật:
#
# $$
# \mathbf{I} = \Delta \mathbf{p} = m \mathbf{v}_2 - m \mathbf{v}_1
# $$
#
# Điều này có nghĩa là khi một lực tác dụng lên một vật trong một khoảng thời gian, nó sẽ làm **thay đổi động lượng** của vật.
# :::
#
# ---
#
# ```{admonition} Ứng dụng 🎯
# - **Bóng đá**: Khi cầu thủ sút bóng, lực tác dụng trong thời gian ngắn làm bóng thay đổi động lượng nhanh chóng.
# - **Đai an toàn trong ô tô**: Giúp kéo dài thời gian thay đổi động lượng khi va chạm, giảm lực tác dụng lên hành khách.
# - **Tàu vũ trụ**: Khi đẩy khí ra ngoài theo một hướng, tàu nhận được một xung lượng theo hướng ngược lại giúp nó di chuyển.
