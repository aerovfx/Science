# %% [markdown]
# # Bài 24: Công Suất
#
# ## 1. Khái Niệm Công Suất
# :::{note}
# **Công suất** là đại lượng đo lường tốc độ thực hiện công của một vật hoặc hệ vật.
# :::
#
# - Công suất cho biết một lực thực hiện công nhanh hay chậm.
# - Đơn vị của công suất là **Watt (W)**.
# - **1 Watt** là công suất của một thiết bị thực hiện **1 Joule công trong 1 giây**.
#
# ---
#
# ## 2. Công Thức Tính Công Suất
# Công suất trung bình được xác định bởi công thức:
#
# $$
# P = \frac{A}{t}
# $$
#
# Trong đó:
# - $ P $ là công suất (W – Watt).
# - $ A $ là công thực hiện (J – Joule).
# - $ t $ là thời gian thực hiện công (s – giây).
#
# **Trường hợp đặc biệt:**
# Nếu công suất không đổi trong khoảng thời gian $ t $, ta có **công suất tức thời**:
#
# $$
# P = F v \cos\theta
# $$
#
# Trong đó:
# - $ F $ là lực tác dụng lên vật (N).
# - $ v $ là vận tốc của vật tại thời điểm xét (m/s).
# - $ \theta $ là góc giữa lực và hướng chuyển động.
#
# ---
#
# ## 3. Liên Hệ Giữa Công Suất Với Lực Và Tốc Độ
# - Khi lực $ F $ cùng phương với vận tốc $ v $ ($ \theta = 0^\circ $), ta có:
#   $$
#   P = F v
#   $$
#   → Công suất đạt giá trị lớn nhất.
#
# - Khi lực vuông góc với vận tốc ($ \theta = 90^\circ $), ta có:
#   $$
#   P = 0
#   $$
#   → Lực không sinh công.
#
# **Ứng dụng thực tế:**
# - Công suất động cơ xe máy, ô tô được tính bằng đơn vị **mã lực (HP)**.
# - Máy móc công nghiệp có công suất lớn để hoạt động hiệu quả hơn.
# - Công suất tiêu thụ điện ảnh hưởng đến hóa đơn tiền điện.
#
# ---
#
# ```{admonition} Lưu ý 📌
# - Công suất giúp đánh giá hiệu quả hoạt động của máy móc.
# - Để tiết kiệm năng lượng, cần chọn thiết bị có công suất phù hợp với nhu cầu sử dụng.
